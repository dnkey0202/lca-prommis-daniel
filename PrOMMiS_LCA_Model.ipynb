# %% [markdown]
# # **<span style="color: black; font-size:1em;">PrOMMiS LCA Integration: Environmental Life Cycle Assessment Using PrOMMiS Modeling Results</span>**

# %% [markdown]
# ## <span style="color:black; font-weight:bold"> Introduction </span>
#
# <span style = "color:black">
# This document demonstrates the application of Life Cycle Assessment (LCA) methodology to the optimized results from the PrOMMiS model.
# This Jupyter Notebook presents an example LCA application to the West Kentucky No.13 Coal Refuse Flowsheet optimized in the PrOMMiS model.
#
# **Useful notes, definitions, and links:**
# - **PrOMMiS model:** Process Optimization and Modeling for Minerals Sustainability initiative, led by the U.S. Department of Energy (DOE), specifically under NETL (National Energy Technology Laboratory).
# - **PrOMMiS public GitHub Repository:** [https://github.com/prommis/prommis/tree/main](https://github.com/prommis/prommis/tree/main)
# - **UKy Flowsheet Code:** [https://github.com/prommis/prommis/blob/main/src/prommis/uky/uky_flowsheet.py](https://github.com/prommis/prommis/blob/main/src/prommis/uky/uky_flowsheet.py)
#
# </span>

# %% [markdown]
# <div style="text-align: center;">
#     <img src="images/uky_flowsheet.png" width="1000"/>
# </div>

# %% [markdown]
# ## <span style="color:black; font-weight:bold"> Step 1: Import the necessary tools </span>

# %%
# import main libraries

import pandas as pd

from netlolca.NetlOlca import NetlOlca

import prommis.uky.uky_flowsheet as uky # module to run the PrOMMiS model
import src as lca_prommis

# %% [markdown]
# ## <span style="color:black; font-weight:bold"> Step 2: Run PrOMMiS Optimization Model for the UKy flowsheet and extract model results </span>

# %%
# Run PrOMMiS model 
m, results = uky.main() 

# Extract LCA data
prommis_data = lca_prommis.data_lca.get_lca_df(m, )
prommis_data.to_csv("lca_df.csv")

# TODO: Leave a note for the user with a link to the prommis repo
# Out:
# Initialization Order
# fs.leach_solid_feed
# fs.leach
# fs.sl_sep1
# fs.leach_mixer
# fs.sc_circuit_purge
# fs.sl_sep2
# fs.precip_sep
# fs.translator_precip_sep_to_purge
# fs.precip_purge
# INFO Starting Sequential Decomposition
# INFO Starting first pass run of network
# 2025-08-22 15:41:09 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.leach_solid_feed
# INFO Initializing fs.leach_solid_feed
# 2025-08-22 15:41:09 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.leach_liquid_feed
# INFO Initializing fs.leach_liquid_feed
# 2025-08-22 15:41:12 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.solex_rougher_load
# INFO Initializing fs.solex_rougher_load
# 2025-08-22 15:41:13 [INFO] idaes.init.fs.solex_rougher_load.mscontactor: Stream Initialization Completed.
# 2025-08-22 15:41:14 [INFO] idaes.init.fs.solex_rougher_load.mscontactor: Initialization Completed, optimal - <undefined>
# 2025-08-22 15:41:14 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.rougher_org_make_up
# INFO Initializing fs.rougher_org_make_up
# 2025-08-22 15:41:14 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.acid_feed1
# INFO Initializing fs.acid_feed1
# 2025-08-22 15:41:14 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.acid_feed2
# INFO Initializing fs.acid_feed2
# 2025-08-22 15:41:14 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.solex_cleaner_load
# INFO Initializing fs.solex_cleaner_load
# WARNING Setting Var 'fs.solex_cleaner_load.mscontactor.aqueous[0.0,1].conc_mol_comp[SO4]' to a numeric value `0.0` outside the bounds (1e-20, None).
# WARNING Setting Var 'fs.solex_cleaner_load.mscontactor.aqueous[0.0,1].conc_mass_comp[SO4]' to a numeric value `-4.547473508864641e-13` outside the bounds (1e-20, None).
# WARNING Setting Var 'fs.solex_cleaner_load.mscontactor.aqueous[0.0,2].conc_mol_comp[SO4]' to a numeric value `0.0` outside the bounds (1e-20, None).
# WARNING Setting Var 'fs.solex_cleaner_load.mscontactor.aqueous[0.0,2].conc_mass_comp[SO4]' to a numeric value `0.0` outside the bounds (1e-20, None).
# WARNING Setting Var 'fs.solex_cleaner_load.mscontactor.aqueous[0.0,3].conc_mol_comp[SO4]' to a numeric value `0.0` outside the bounds (1e-20, None).
# WARNING Setting Var 'fs.solex_cleaner_load.mscontactor.aqueous[0.0,3].conc_mass_comp[SO4]' to a numeric value `-4.547473508864641e-13` outside the bounds (1e-20, None).
# 2025-08-22 15:41:16 [INFO] idaes.init.fs.solex_cleaner_load.mscontactor: Stream Initialization Completed.
# 2025-08-22 15:41:16 [INFO] idaes.init.fs.solex_cleaner_load.mscontactor: Initialization Completed, optimal - <undefined>
# 2025-08-22 15:41:17 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.cleaner_org_make_up
# INFO Initializing fs.cleaner_org_make_up
# 2025-08-22 15:41:17 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.acid_feed3
# INFO Initializing fs.acid_feed3
# 2025-08-22 15:41:17 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.leach
# INFO Initializing fs.leach
# 2025-08-22 15:41:18 [INFO] idaes.init.fs.leach.mscontactor: Stream Initialization Completed.
# 2025-08-22 15:41:18 [INFO] idaes.init.fs.leach.mscontactor: Initialization Completed, optimal - <undefined>
# 2025-08-22 15:41:18 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.load_sep
# INFO Initializing fs.load_sep
# 2025-08-22 15:41:19 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.solex_rougher_scrub
# INFO Initializing fs.solex_rougher_scrub
# WARNING Setting Var 'fs.solex_rougher_scrub.mscontactor.aqueous[0.0,1].conc_mol_comp[SO4]' to a numeric value `0.0` outside the bounds (1e-20, None).
# WARNING Setting Var 'fs.solex_rougher_scrub.mscontactor.aqueous[0.0,1].conc_mass_comp[SO4]' to a numeric value `0.0` outside the bounds (1e-20, None).
# 2025-08-22 15:41:20 [INFO] idaes.init.fs.solex_rougher_scrub.mscontactor: Stream Initialization Completed.
# 2025-08-22 15:41:20 [INFO] idaes.init.fs.solex_rougher_scrub.mscontactor: Initialization Completed, optimal - <undefined>
# 2025-08-22 15:41:20 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.solex_cleaner_strip
# INFO Initializing fs.solex_cleaner_strip
# 2025-08-22 15:41:21 [INFO] idaes.init.fs.solex_cleaner_strip.mscontactor: Stream Initialization Completed.
# 2025-08-22 15:41:22 [INFO] idaes.init.fs.solex_cleaner_strip.mscontactor: Initialization Completed, optimal - <undefined>
# 2025-08-22 15:41:22 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.sl_sep1
# INFO Initializing fs.sl_sep1
# 2025-08-22 15:41:23 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.scrub_sep
# INFO Initializing fs.scrub_sep
# 2025-08-22 15:41:23 [INFO] idaes.init.fs.scrub_sep: Initialization Step 2 Complete: optimal - <undefined>
# 2025-08-22 15:41:23 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.solex_rougher_strip
# INFO Initializing fs.solex_rougher_strip
# 2025-08-22 15:41:24 [INFO] idaes.init.fs.solex_rougher_strip.mscontactor: Stream Initialization Completed.
# 2025-08-22 15:41:24 [INFO] idaes.init.fs.solex_rougher_strip.mscontactor: Initialization Completed, optimal - <undefined>
# 2025-08-22 15:41:25 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.cleaner_sep
# INFO Initializing fs.cleaner_sep
# 2025-08-22 15:41:25 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.translator_leaching_to_precipitate
# INFO Initializing fs.translator_leaching_to_precipitate
# WARNING Setting Var 'fs.translator_leaching_to_precipitate.properties_out[0.0].conc_mol_comp[HSO4]' to a numeric value `9.150441149140002e-16` outside the bounds (9.999999999999999e-16, None).
# 2025-08-22 15:41:25 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.leach_mixer
# INFO Initializing fs.leach_mixer
# 2025-08-22 15:41:25 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.leach_filter_cake
# INFO Initializing fs.leach_filter_cake
# 2025-08-22 15:41:25 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.leach_filter_cake_liquid
# INFO Initializing fs.leach_filter_cake_liquid
# 2025-08-22 15:41:25 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.leach_sx_mixer
# INFO Initializing fs.leach_sx_mixer
# 2025-08-22 15:41:26 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.rougher_sep
# INFO Initializing fs.rougher_sep
# 2025-08-22 15:41:26 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.cleaner_mixer
# INFO Initializing fs.cleaner_mixer
# 2025-08-22 15:41:26 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.cleaner_purge
# INFO Initializing fs.cleaner_purge
# 2025-08-22 15:41:26 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.precipitator
# INFO Initializing fs.precipitator
# WARNING Setting Var 'fs.precipitator.cv_aqueous.properties_out[0.0].conc_mol_comp[HSO4]' to a numeric value `9.150441149140002e-16` outside the bounds (9.999999999999999e-16, None).
# WARNING Setting Var 'fs.precipitator.cv_aqueous.properties_in[0.0].conc_mol_comp[HSO4]' to a numeric value `9.150441149140002e-16` outside the bounds (9.999999999999999e-16, None).
# 2025-08-22 15:41:27 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.sc_circuit_purge
# INFO Initializing fs.sc_circuit_purge
# 2025-08-22 15:41:27 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.rougher_mixer
# INFO Initializing fs.rougher_mixer
# 2025-08-22 15:41:27 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.translator_precipitate_to_leaching
# INFO Initializing fs.translator_precipitate_to_leaching
# WARNING Setting Var 'fs.translator_precipitate_to_leaching.properties_in[0.0].conc_mol_comp[HSO4]' to a numeric value `9.150441149140002e-16` outside the bounds (9.999999999999999e-16, None).
# 2025-08-22 15:41:27 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.sl_sep2
# INFO Initializing fs.sl_sep2
# WARNING Setting Var 'fs.sl_sep2.split.recovered_state[0.0].conc_mol_comp[SO4]' to a numeric value `0.0` outside the bounds (1e-20, None).
# WARNING Setting Var 'fs.sl_sep2.split.recovered_state[0.0].conc_mass_comp[SO4]' to a numeric value `0.0` outside the bounds (1e-20, None).
# WARNING Setting Var 'fs.sl_sep2.split.retained_state[0.0].conc_mol_comp[SO4]' to a numeric value `0.0` outside the bounds (1e-20, None).
# WARNING Setting Var 'fs.sl_sep2.split.retained_state[0.0].conc_mass_comp[SO4]' to a numeric value `0.0` outside the bounds (1e-20, None).
# WARNING Setting Var 'fs.precip_sep.mixed_state[0.0].conc_mass_comp[SO4]' to a numeric value `-0.0` outside the bounds (1e-20, None).
# WARNING Setting Var 'fs.translator_sep_to_roast.properties_in[0.0].conc_mass_comp[SO4]' to a numeric value `-0.0` outside the bounds (1e-20, None).
# 2025-08-22 15:41:28 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.precip_sep
# INFO Initializing fs.precip_sep
# WARNING Setting Var 'fs.precip_sep.mixed_state[0.0].conc_mol_comp[SO4]' to a numeric value `2.312964634635742e-21` outside the bounds (1e-20, None).
# WARNING Setting Var 'fs.precip_sep.mixed_state[0.0].conc_mass_comp[SO4]' to a numeric value `-0.0` outside the bounds (1e-20, None).
# WARNING Setting Var 'fs.precip_sep.recycle_state[0.0].conc_mass_comp[SO4]' to a numeric value `-0.0` outside the bounds (1e-20, None).
# WARNING Setting Var 'fs.precip_sep.recycle_state[0.0].conc_mol_comp[SO4]' to a numeric value `2.312964634635742e-21` outside the bounds (1e-20, None).
# WARNING Setting Var 'fs.precip_sep.purge_state[0.0].conc_mass_comp[SO4]' to a numeric value `-0.0` outside the bounds (1e-20, None).
# WARNING Setting Var 'fs.precip_sep.purge_state[0.0].conc_mol_comp[SO4]' to a numeric value `2.312964634635742e-21` outside the bounds (1e-20, None).
# WARNING Setting Var 'fs.precip_sep.mixed_state[0.0].conc_mol_comp[SO4]' to a numeric value `0.0` outside the bounds (1e-20, None).
# 2025-08-22 15:41:28 [INFO] idaes.init.fs.precip_sep: Initialization Step 2 Complete: optimal - <undefined>
# WARNING Setting Var 'fs.precip_sep.mixed_state[0.0].conc_mass_comp[SO4]' to a numeric value `-0.0` outside the bounds (1e-20, None).
# WARNING Setting Var 'fs.precip_sep.mixed_state[0.0].conc_mass_comp[SO4]' to a numeric value `-0.0` outside the bounds (1e-20, None).
# 2025-08-22 15:41:28 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.translator_sep_to_roast
# INFO Initializing fs.translator_sep_to_roast
# WARNING Setting Var 'fs.translator_sep_to_roast.properties_out[0.0].conc_mass_comp[SO4]' to a numeric value `0.0` outside the bounds (1e-20, None).
# WARNING Setting Var 'fs.translator_sep_to_roast.properties_out[0.0].conc_mol_comp[SO4]' to a numeric value `-0.0` outside the bounds (9.999999999999999e-16, None).
# WARNING Setting Var 'fs.translator_sep_to_roast.properties_in[0.0].conc_mol_comp[SO4]' to a numeric value `2.312964634635742e-21` outside the bounds (1e-20, None).
# WARNING Setting Var 'fs.translator_sep_to_roast.properties_in[0.0].conc_mass_comp[SO4]' to a numeric value `-0.0` outside the bounds (1e-20, None).
# WARNING Setting Var 'fs.translator_sep_to_roast.properties_in[0.0].conc_mass_comp[SO4]' to a numeric value `-0.0` outside the bounds (1e-20, None).
# WARNING Setting Var 'fs.roaster.liquid_in[0.0].conc_mass_comp[SO4]' to a numeric value `-0.0` outside the bounds (1e-20, None).
# 2025-08-22 15:41:28 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.translator_precip_sep_to_purge
# INFO Initializing fs.translator_precip_sep_to_purge
# 2025-08-22 15:41:29 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.precip_sx_mixer
# INFO Initializing fs.precip_sx_mixer
# 2025-08-22 15:41:29 [INFO] idaes.init.fs.precip_sx_mixer: Initialization Complete: optimal - <undefined>
# 2025-08-22 15:41:29 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.roaster
# INFO Initializing fs.roaster
# WARNING Setting Var 'fs.roaster.liquid_in[0.0].conc_mol_comp[SO4]' to a numeric value `-0.0` outside the bounds (9.999999999999999e-16, None).
# WARNING Setting Var 'fs.roaster.liquid_in[0.0].conc_mass_comp[SO4]' to a numeric value `-0.0` outside the bounds (1e-20, None).
# WARNING Setting Var 'fs.roaster.liquid_in[0.0].conc_mass_comp[SO4]' to a numeric value `-0.0` outside the bounds (1e-20, None).
# 2025-08-22 15:41:30 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.precip_purge
# INFO Initializing fs.precip_purge
# INFO Starting tear convergence procedure
# 2025-08-22 15:41:30 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.leach_solid_feed
# INFO Initializing fs.leach_solid_feed
# 2025-08-22 15:41:30 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.leach_liquid_feed
# INFO Initializing fs.leach_liquid_feed
# 2025-08-22 15:41:30 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.rougher_org_make_up
# INFO Initializing fs.rougher_org_make_up
# 2025-08-22 15:41:30 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.acid_feed1
# INFO Initializing fs.acid_feed1
# 2025-08-22 15:41:30 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.acid_feed2
# INFO Initializing fs.acid_feed2
# 2025-08-22 15:41:30 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.cleaner_org_make_up
# INFO Initializing fs.cleaner_org_make_up
# 2025-08-22 15:41:31 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.acid_feed3
# INFO Initializing fs.acid_feed3
# INFO Starting Direct tear convergence
# INFO Running Direct iteration 1
# 2025-08-22 15:41:31 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.solex_cleaner_load
# INFO Initializing fs.solex_cleaner_load
# WARNING Setting Var 'fs.solex_cleaner_load.mscontactor.aqueous[0.0,1].conc_mol_comp[HSO4]' to a numeric value `0.0` outside the bounds (1e-20, None).
# WARNING Setting Var 'fs.solex_cleaner_load.mscontactor.aqueous[0.0,1].conc_mass_comp[HSO4]' to a numeric value `0.0` outside the bounds (1e-20, None).
# WARNING Setting Var 'fs.solex_cleaner_load.mscontactor.aqueous[0.0,2].conc_mol_comp[HSO4]' to a numeric value `0.0` outside the bounds (1e-20, None).
# WARNING Setting Var 'fs.solex_cleaner_load.mscontactor.aqueous[0.0,2].conc_mass_comp[HSO4]' to a numeric value `0.0` outside the bounds (1e-20, None).
# WARNING Setting Var 'fs.solex_cleaner_load.mscontactor.aqueous[0.0,3].conc_mol_comp[HSO4]' to a numeric value `0.0` outside the bounds (1e-20, None).
# WARNING Setting Var 'fs.solex_cleaner_load.mscontactor.aqueous[0.0,3].conc_mass_comp[HSO4]' to a numeric value `0.0` outside the bounds (1e-20, None).
# 2025-08-22 15:41:32 [INFO] idaes.init.fs.solex_cleaner_load.mscontactor: Stream Initialization Completed.
# 2025-08-22 15:41:32 [INFO] idaes.init.fs.solex_cleaner_load.mscontactor: Initialization Completed, optimal - <undefined>
# 2025-08-22 15:41:32 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.solex_rougher_load
# INFO Initializing fs.solex_rougher_load
# 2025-08-22 15:41:33 [INFO] idaes.init.fs.solex_rougher_load.mscontactor: Stream Initialization Completed.
# 2025-08-22 15:41:33 [INFO] idaes.init.fs.solex_rougher_load.mscontactor: Initialization Completed, optimal - <undefined>
# 2025-08-22 15:41:34 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.leach
# INFO Initializing fs.leach
# 2025-08-22 15:41:34 [INFO] idaes.init.fs.leach.mscontactor: Stream Initialization Completed.
# 2025-08-22 15:41:35 [INFO] idaes.init.fs.leach.mscontactor: Initialization Completed, optimal - <undefined>
# 2025-08-22 15:41:35 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.solex_cleaner_strip
# INFO Initializing fs.solex_cleaner_strip
# 2025-08-22 15:41:36 [INFO] idaes.init.fs.solex_cleaner_strip.mscontactor: Stream Initialization Completed.
# 2025-08-22 15:41:36 [INFO] idaes.init.fs.solex_cleaner_strip.mscontactor: Initialization Completed, optimal - <undefined>
# 2025-08-22 15:41:36 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.solex_rougher_scrub
# INFO Initializing fs.solex_rougher_scrub
# WARNING Setting Var 'fs.solex_rougher_scrub.mscontactor.aqueous[0.0,1].conc_mol_comp[SO4]' to a numeric value `0.0` outside the bounds (1e-20, None).
# WARNING Setting Var 'fs.solex_rougher_scrub.mscontactor.aqueous[0.0,1].conc_mass_comp[SO4]' to a numeric value `0.0` outside the bounds (1e-20, None).
# 2025-08-22 15:41:37 [INFO] idaes.init.fs.solex_rougher_scrub.mscontactor: Stream Initialization Completed.
# 2025-08-22 15:41:37 [INFO] idaes.init.fs.solex_rougher_scrub.mscontactor: Initialization Completed, optimal - <undefined>
# 2025-08-22 15:41:37 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.load_sep
# INFO Initializing fs.load_sep
# 2025-08-22 15:41:37 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.sl_sep1
# INFO Initializing fs.sl_sep1
# 2025-08-22 15:41:38 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.leach_sx_mixer
# INFO Initializing fs.leach_sx_mixer
# 2025-08-22 15:41:38 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.translator_leaching_to_precipitate
# INFO Initializing fs.translator_leaching_to_precipitate
# WARNING Setting Var 'fs.translator_leaching_to_precipitate.properties_out[0.0].conc_mol_comp[HSO4]' to a numeric value `9.96865695213875e-16` outside the bounds (9.999999999999999e-16, None).
# WARNING Setting Var 'fs.translator_leaching_to_precipitate.properties_in[0.0].conc_mol_comp[HSO4]' to a numeric value `-2.9190421124267895e-17` outside the bounds (1e-20, None).
# 2025-08-22 15:41:39 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.cleaner_sep
# INFO Initializing fs.cleaner_sep
# WARNING Setting Var 'fs.cleaner_sep.purge_state[0.0].conc_mass_comp[Pr_o]' to a numeric value `-4.175129599208333e-09` outside the bounds (1e-20, None).
# WARNING Setting Var 'fs.cleaner_sep.purge_state[0.0].conc_mol_comp[Pr_o]' to a numeric value `-2.963039167116133e-14` outside the bounds (1e-20, None).
# 2025-08-22 15:41:39 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.solex_rougher_strip
# INFO Initializing fs.solex_rougher_strip
# 2025-08-22 15:41:39 [INFO] idaes.init.fs.solex_rougher_strip.mscontactor: Stream Initialization Completed.
# 2025-08-22 15:41:40 [INFO] idaes.init.fs.solex_rougher_strip.mscontactor: Initialization Completed, optimal - <undefined>
# 2025-08-22 15:41:40 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.scrub_sep
# INFO Initializing fs.scrub_sep
# 2025-08-22 15:41:40 [INFO] idaes.init.fs.scrub_sep: Initialization Step 2 Complete: optimal - <undefined>
# 2025-08-22 15:41:40 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.precipitator
# INFO Initializing fs.precipitator
# WARNING Setting Var 'fs.precipitator.cv_aqueous.properties_out[0.0].conc_mol_comp[HSO4]' to a numeric value `9.968693460109563e-16` outside the bounds (9.999999999999999e-16, None).
# WARNING Setting Var 'fs.precipitator.cv_aqueous.properties_in[0.0].conc_mol_comp[HSO4]' to a numeric value `9.96865695213875e-16` outside the bounds (9.999999999999999e-16, None).
# 2025-08-22 15:41:40 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.cleaner_mixer
# INFO Initializing fs.cleaner_mixer
# 2025-08-22 15:41:40 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.rougher_sep
# INFO Initializing fs.rougher_sep
# 2025-08-22 15:41:41 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.leach_mixer
# INFO Initializing fs.leach_mixer
# 2025-08-22 15:41:41 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.translator_precipitate_to_leaching
# INFO Initializing fs.translator_precipitate_to_leaching
# WARNING Setting Var 'fs.translator_precipitate_to_leaching.properties_out[0.0].conc_mol_comp[HSO4]' to a numeric value `-2.9186770327186533e-17` outside the bounds (1e-20, None).
# WARNING Setting Var 'fs.translator_precipitate_to_leaching.properties_in[0.0].conc_mol_comp[HSO4]' to a numeric value `9.968693460109563e-16` outside the bounds (9.999999999999999e-16, None).
# 2025-08-22 15:41:41 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.rougher_mixer
# INFO Initializing fs.rougher_mixer
# 2025-08-22 15:41:41 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.sl_sep2
# INFO Initializing fs.sl_sep2
# WARNING Setting Var 'fs.sl_sep2.liquid_inlet_state[0.0].conc_mol_comp[HSO4]' to a numeric value `-2.9186770327186533e-17` outside the bounds (1e-20, None).
# WARNING Setting Var 'fs.sl_sep2.split.recovered_state[0.0].conc_mol_comp[HSO4]' to a numeric value `0.0` outside the bounds (1e-20, None).
# WARNING Setting Var 'fs.sl_sep2.split.recovered_state[0.0].conc_mass_comp[HSO4]' to a numeric value `0.0` outside the bounds (1e-20, None).
# WARNING Setting Var 'fs.precip_sep.mixed_state[0.0].conc_mass_comp[HSO4]' to a numeric value `-0.0` outside the bounds (1e-20, None).
# 2025-08-22 15:41:42 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.precip_sep
# INFO Initializing fs.precip_sep
# WARNING Setting Var 'fs.precip_sep.mixed_state[0.0].conc_mol_comp[HSO4]' to a numeric value `-0.0` outside the bounds (1e-20, None).
# WARNING Setting Var 'fs.precip_sep.mixed_state[0.0].conc_mass_comp[HSO4]' to a numeric value `-0.0` outside the bounds (1e-20, None).
# WARNING Setting Var 'fs.precip_sep.recycle_state[0.0].conc_mass_comp[HSO4]' to a numeric value `-0.0` outside the bounds (1e-20, None).
# WARNING Setting Var 'fs.precip_sep.recycle_state[0.0].conc_mol_comp[HSO4]' to a numeric value `-0.0` outside the bounds (1e-20, None).
# WARNING Setting Var 'fs.precip_sep.purge_state[0.0].conc_mass_comp[HSO4]' to a numeric value `-0.0` outside the bounds (1e-20, None).
# WARNING Setting Var 'fs.precip_sep.purge_state[0.0].conc_mol_comp[HSO4]' to a numeric value `2.7288432579068945e-28` outside the bounds (1e-20, None).
# WARNING Setting Var 'fs.precip_sep.mixed_state[0.0].conc_mol_comp[HSO4]' to a numeric value `0.0` outside the bounds (1e-20, None).
# 2025-08-22 15:41:42 [INFO] idaes.init.fs.precip_sep: Initialization Step 2 Complete: optimal - <undefined>
# WARNING Setting Var 'fs.precip_sep.mixed_state[0.0].conc_mass_comp[HSO4]' to a numeric value `-0.0` outside the bounds (1e-20, None).
# WARNING Setting Var 'fs.precip_sep.mixed_state[0.0].conc_mass_comp[HSO4]' to a numeric value `-0.0` outside the bounds (1e-20, None).
# 2025-08-22 15:41:42 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.precip_sx_mixer
# INFO Initializing fs.precip_sx_mixer
# 2025-08-22 15:41:43 [INFO] idaes.init.fs.precip_sx_mixer: Initialization Complete: optimal - <undefined>
# WARNING Direct failed to converge in 1 iterations
# 2025-08-22 15:41:43 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.leach_filter_cake
# INFO Initializing fs.leach_filter_cake
# 2025-08-22 15:41:43 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.leach_filter_cake_liquid
# INFO Initializing fs.leach_filter_cake_liquid
# 2025-08-22 15:41:43 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.sc_circuit_purge
# INFO Initializing fs.sc_circuit_purge
# 2025-08-22 15:41:43 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.cleaner_purge
# INFO Initializing fs.cleaner_purge
# 2025-08-22 15:41:43 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.translator_precip_sep_to_purge
# INFO Initializing fs.translator_precip_sep_to_purge
# WARNING Setting Var 'fs.translator_sep_to_roast.properties_in[0.0].conc_mass_comp[SO4]' to a numeric value `-0.0` outside the bounds (1e-20, None).
# 2025-08-22 15:41:43 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.translator_sep_to_roast
# INFO Initializing fs.translator_sep_to_roast
# WARNING Setting Var 'fs.translator_sep_to_roast.properties_out[0.0].conc_mass_comp[SO4]' to a numeric value `0.0` outside the bounds (1e-20, None).
# WARNING Setting Var 'fs.translator_sep_to_roast.properties_out[0.0].conc_mol_comp[SO4]' to a numeric value `-0.0` outside the bounds (9.999999999999999e-16, None).
# WARNING Setting Var 'fs.translator_sep_to_roast.properties_in[0.0].conc_mol_comp[SO4]' to a numeric value `-2.2204229196039662e-16` outside the bounds (1e-20, None).
# WARNING Setting Var 'fs.translator_sep_to_roast.properties_in[0.0].conc_mass_comp[SO4]' to a numeric value `-0.0` outside the bounds (1e-20, None).
# WARNING Setting Var 'fs.translator_sep_to_roast.properties_in[0.0].conc_mass_comp[SO4]' to a numeric value `-0.0` outside the bounds (1e-20, None).
# WARNING Setting Var 'fs.roaster.liquid_in[0.0].conc_mass_comp[SO4]' to a numeric value `-0.0` outside the bounds (1e-20, None).
# 2025-08-22 15:41:44 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.roaster
# INFO Initializing fs.roaster
# WARNING Setting Var 'fs.roaster.liquid_in[0.0].conc_mol_comp[SO4]' to a numeric value `-0.0` outside the bounds (9.999999999999999e-16, None).
# WARNING Setting Var 'fs.roaster.liquid_in[0.0].conc_mass_comp[SO4]' to a numeric value `-0.0` outside the bounds (1e-20, None).
# WARNING Setting Var 'fs.roaster.liquid_in[0.0].conc_mass_comp[SO4]' to a numeric value `-0.0` outside the bounds (1e-20, None).
# 2025-08-22 15:41:45 [INFO] idaes.prommis.uky.uky_flowsheet: Initializing fs.precip_purge
# INFO Initializing fs.precip_purge
# INFO Finished Sequential Decomposition in 36.02 seconds
#
# ====================================================================================
# Unit : fs.roaster                                                          Time: 0.0
# ------------------------------------------------------------------------------------
#     Unit Performance
#
#
#     Expressions:
#
#     Key                      : Value      : Units
#     Product Al Mass Fraction :  0.0058911 : dimensionless
#     Product Ca Mass Fraction :   0.033494 : dimensionless
#     Product Ce Mass Fraction :   0.024002 : dimensionless
#     Product Dy Mass Fraction :    0.15245 : dimensionless
#     Product Fe Mass Fraction :    0.22313 : dimensionless
#     Product Gd Mass Fraction :    0.30557 : dimensionless
#     Product La Mass Fraction :   0.013938 : dimensionless
#     Product Nd Mass Fraction :   0.015931 : dimensionless
#     Product Pr Mass Fraction :  0.0047032 : dimensionless
#     Product Sc Mass Fraction : 0.00012336 : dimensionless
#     Product Sm Mass Fraction :   0.019129 : dimensionless
#      Product Y Mass Fraction :    0.20118 : dimensionless
#
# ------------------------------------------------------------------------------------
#     Stream Table
#     Empty DataFrame
#     Columns: [Units]
#     Index: []
# ====================================================================================
# REE product mass flow is 1.3526126774548411e-05 kg/hr
# REE feed mass flow is 0.0072125826098036324 kg/hr
# Total REE recovery is 0.18753513833121516 %
# Product purity is 62.29112748670729 % REE
#
# Leaching Aluminum recovery is 6.595853821352803 %
# Total aluminum recovery is 2.3798505329590416e-06 %
#
# Leaching Calcium recovery is 43.76398796099143 %
# Total Calcium recovery is 0.0009688250793400597 %
#
# Leaching Cerium recovery is 41.83736206754961 %
# Total Cerium recovery is 0.014715712038792565 %
#
# Leaching Dysprosium recovery is 14.84734968351877 %
# Total Dysprosium recovery is 1.93363114448774 %
#
# Leaching Iron recovery is 22.138355153828922 %
# Total Iron recovery is 0.0003327607903541326 %
#
# Leaching Gadolinium recovery is 57.8642799561053 %
# Total Gadolinium recovery is 2.8117891396281847 %
#
# Leaching Lanthanum recovery is 37.331946792457074 %
# Total Lanthanum recovery is 0.019689008998648755 %
#
# Leaching Neodymium recovery is 45.593302615020725 %
# Total Neodymium recovery is 0.02254302723792359 %
#
# Leaching Praseodymium recovery is 45.228755443935576 %
# Total Praseodymium recovery is 0.02626582954773118 %
#
# Leaching Scandium recovery is 3.389628531841224 %
# Total Scandium recovery is 0.0004249009697483163 %
#
# Leaching Samarium recovery is 26.114810517605143 %
# Total Samarium recovery is 0.12380798152862897 %
#
# Leaching Yttrium recovery is 9.75965988580635 %
# Total Yttrium recovery is 0.5860813419521571 %
# WARNING model contains export suffix 'scaling_factor' that contains 192 component keys that are not exported as part of the NL file.  Skipping.
# WARNING model contains export suffix 'scaling_factor' that contains 192 component keys that are not exported as part of the NL file.  Skipping.
#
# ====================================================================================
# costing
# ------------------------------------------------------------------------------------
#                                                                              Value
#     Plant Cost Units                                                      MUSD_UKy_2019
#     Total Plant Cost                                                             1.1807
#     Total Bare Erected Cost                                                     0.39754
#     Total Installation Cost                                                     0.78316
#     Total Other Plant Costs                                                  7.5987e-06
#     Summation of Ancillary Installation Costs                                   0.23058
#     Total Ancillary Piping, Materials and Labor Installation Cost              0.079509
#     Total Ancillary Electrical, Materials and Labor Installation Cost          0.079509
#     Total Ancillary Instrumentation Installation Cost                          0.031803
#     Total Ancillary Plant Services Installation Cost                           0.039754
#     Summation of Buildings Installation Costs                                   0.25840
#     Total Process Buildings Installation Cost                                   0.15902
#     Total Auxiliary Buildings Installation Cost                                0.059631
#     Total Site Improvements Buildings Installation Cost                        0.039754
#     Summation of EPCM Installation Costs                                        0.23455
#     Total Equipment Installation EPCM Installation Cost                        0.067582
#     Total Field Expenses EPCM Cost                                             0.047705
#     Total Project Management and Construction EPCM Installation Cost            0.11926
#     Total Process Contingency Installation Cost                                0.059631
#     Summation of Contingency Installation Costs                                0.059631
#     Total Fixed Operating & Maintenance Cost                                     6.8166
#     Total Annual Operating Labor Cost                                            3.8090
#     Total Annual Technical Labor Cost                                            1.8294
#     Summation of Annual Labor Costs                                              5.6384
#     Total Maintenance and Material Cost                                        0.023614
#     Total Quality Assurance and Control Cost                                    0.38090
#     Total Sales, Patenting and Research Cost                                 1.3472e-07
#     Summation of Sales, Admin and Insurance Cost                                0.77361
#     Total Admin Support and Labor Cost                                          0.76181
#     Total Property Taxes and Insurance Cost                                    0.011807
#     Total Other Fixed Costs                                                  1.0000e-12
#     Total Variable Power Cost                                                1.6095e-05
#     Total Variable Waste Cost                                                1.9833e-10
#     Total Variable Chemicals Cost                                                0.0000
#     General Plant Overhead Cost                                                  1.3633
#     Total Plant Overhead Cost, Including Maintenance & Quality Assurance         1.7678
#     Total Variable Operating & Maintenance Cost                                  1.3634
#     Total Land Cost                                                          6.1234e-05
#     Total Sales Revenue Cost                                                 2.6943e-05
# ====================================================================================
#
# variable_operating_costs : Variable operating costs
#     Size=4, Index=fs._time*{nonhazardous_solid_waste, nonhazardous_precipitate_waste, dust_and_volatiles, power}, Units=MUSD_UKy_2019/a
#     Key                                     : Lower : Value                   : Upper : Fixed : Stale : Domain
#                 (0.0, 'dust_and_volatiles') :  None : -2.4678647039471923e-16 :  None : False : False :  Reals
#     (0.0, 'nonhazardous_precipitate_waste') :  None :  1.4725952899780669e-16 :  None : False : False :  Reals
#           (0.0, 'nonhazardous_solid_waste') :  None :  1.9833221821569988e-10 :  None : False : False :  Reals
#                              (0.0, 'power') :  None :   1.609502393003431e-05 :  None : False : False :  Reals
# -----Bare Erected Costs-----
# fs.leach.costing: 0.00037
# fs.sl_sep1.costing: 0.00198
# fs.leach_mixer.costing: 0.00437
# fs.rougher_mixer.costing: 0.00168
# fs.cleaner_mixer.costing: 0.00022
# fs.leach_sx_mixer.costing: 0.00035
# fs.precipitator.costing: 0.00001
# fs.sl_sep2.costing: 0.00001
# fs.roaster.costing: 0.03697
# fs.leach_pump.costing: 0.01446
# fs.leach_solution_heater.costing: 0.00001
# fs.rougher_solex_tank.costing: 0.00013
# fs.rougher_pump.costing: 0.00711
# fs.rougher_solex_settler.costing: 0.27010
# fs.cleaner_solex_tank.costing: 0.00000
# fs.cleaner_pump.costing: 0.00532
# fs.cleaner_solex_settler.costing: 0.05272
# fs.precipitator_mixer.costing: 0.00033
# fs.precipitator_pump.costing: 0.00141
#
#
# Total bare erected cost: 0.398
# Total overnight (installed) equipment cost: 1.181
# Total annualized capital cost: 0.135
#
# Total annual fixed O&M cost: 6.817
# Total annual variable O&M cost: 1.363
# Total annual O&M cost: 8.180
# Total annual O&M cost per ton feed processed: 40575.342
# Total annual O&M cost per kg REE recovered: 46650263.220
#
# Total annualized plant cost: 8.315
# Annual rate of recovery: 0.175 kg/year REE recovered
# Cost of recovery per kg REE recovered: 47422123.639
#
#
#
# REE mass in: 0.008490363915600001 kg/hr
# REE mass out: 1.5965288953841767e-05 kg/hr
# Product purity: 73.42243050250583%
# Recovery: 0.18804010184425088%

# %% [markdown]
# ## <span style="color:black; font-weight:bold"> Step 3: Review PrOMMiS Results </span>

# %%
prommis_data.head()
# Out:
#               Flow      Source In/Out     Category  Value 1 Unit 1   Value 2  \
# 0           Inerts  Solid Feed     In  Solid Input    22.68  kg/hr    0.6952
# 1   Scandium Oxide  Solid Feed     In  Solid Input    22.68  kg/hr  0.000028
# 2    Yttrium Oxide  Solid Feed     In  Solid Input    22.68  kg/hr  0.000033
# 3  Lanthanum Oxide  Solid Feed     In  Solid Input    22.68  kg/hr  0.000068
# 4     Cerium Oxide  Solid Feed     In  Solid Input    22.68  kg/hr  0.000156
#
#           Unit 2
# 0  mass fraction
# 1  mass fraction
# 2  mass fraction
# 3  mass fraction
# 4  mass fraction

# %% [markdown]
# ## <span style="color:black; font-weight:bold"> Step 4: Organize, Categorize, and Covert PrOMMiS Results to LCA Relevant Flows </span>

# %%
# Hours is the time period for the conversion
# mol_to_kg is a boolean that indicates whether to convert moles to kg
# water_unit is the unit of water (m3 or L recommended, kg is also an option)
df = lca_prommis.convert_lca.convert_flows_to_lca_units(prommis_data, hours=1, mol_to_kg=True, water_unit='m3')
df.to_csv('lca_df_converted.csv', index=False)

# Finalize the LCA data
df = pd.read_csv('lca_df_converted.csv')
df = lca_prommis.final_lca.main()
df.to_csv('lca_df_finalized.csv', index=False)

# This will create a new datafrane and csv file that contains the initial prommis_data df with two additional columns:
# 'LCA Amount' and 'LCA Unit'
# Out:
# WARNING Dynamically registering the following numeric type:
#     pymatgen.core.units.FloatWithUnit
# Dynamic registration is supported for convenience, but there are known
# limitations to this approach.  We recommend explicitly registering
# numeric types using RegisterNumericType() or RegisterIntegerType().
# Applied functional unit conversion with scaling factor: 1.5965288953841764e-05
# Reference flow: 99.85% REO Product from Roaster Product
# INFO Returning C:\Users\franc\AppData\Local\fedelemflowlist\FedElemFlowListMaster_v1.3.0_a79846d.parquet
# Summary:
#   total_flows: 17
#   input_flows: 10
#   output_flows: 7
#   reference_products: 1
#   unique_flow_types: 9
#   total_lca_amount: 26057242.590626873
#
# Flow Type Breakdown:
#   Chemicals: 6
#   Emissions to air: 4
#   Solid Input: 1
#   Solid Output: 1
#   Electricity: 1
#   Heat: 1
#   Solid Waste: 1
#   Wastewater: 1
#   Water: 1

# %% [markdown]
# ## <span style="color:black; font-weight:bold"> Step 5: Normalize Flows to the Selected Functional Unit and Review Final LCA Flows </span>

# %%
# The below code will normalize the converted prommis data to a functional unit
# Note: This code is developed for the UKy flowsheet and the functional unit is automatically set to 1 kg of REO (combination of all REEs)
# TODO: This code should be developed for the other flowsheets. To achieve this, the user should be able to specify the desired functional unit
df = pd.read_csv('lca_df_converted.csv')

# Run the merge_flows function for the feed
REO_list = [
    "Yttrium Oxide",
    "Lanthanum Oxide",
    "Cerium Oxide",
    "Praseodymium Oxide",
    "Neodymium Oxide",
    "Samarium Oxide",
    "Gadolinium Oxide",
    "Dysprosium Oxide",
]
df = lca_prommis.final_lca.merge_flows(df, merge_source='Solid Feed', new_flow_name='374 ppm REO Feed', value_2_merge=REO_list)
# This 374 ppm value is directly calculated from the flowsheet. The original study actually used 357 ppm as the feed concentration.

# Run the merge_flows function for the product
df = lca_prommis.final_lca.merge_flows(df, merge_source='Roaster Product', new_flow_name='99.85% REO Product')

# Run the merge_flows function for the liquid waste flows
df = lca_prommis.final_lca.merge_flows(df, merge_source='Wastewater', new_flow_name='Wastewater', merge_column='Category') 
# Note: some of these streams are organic waste, but they're treated as wastewater

# Run the merge_flows function for the solid waste flows
df = lca_prommis.final_lca.merge_flows(df, merge_source='Solid Waste', new_flow_name='Solid Waste', merge_column='Category') 

# Run the finalize_df function
try:
    finalized_df = lca_prommis.final_lca.finalize_df(
        df=df, 
        reference_flow='99.85% REO Product', 
        reference_source='Roaster Product',
        water_type='raw fresh water'
    )
    
    # Get summary
    summary = lca_prommis.final_lca.get_finalize_summary(finalized_df)
    print("Summary:")
    for key, value in summary.items():
        if key != 'flow_type_breakdown':
            print(f"  {key}: {value}")
    
    print("\nFlow Type Breakdown:")
    for flow_type, count in summary['flow_type_breakdown'].items():
        print(f"  {flow_type}: {count}")
        
except Exception as e:
    print(f"Error during finalization: {e}")

finalized_df.to_csv('lca_df_finalized.csv', index=False)
# Out:
# Applied functional unit conversion with scaling factor: 1.5965288953841764e-05
# Reference flow: 99.85% REO Product from Roaster Product
# INFO Returning C:\Users\franc\AppData\Local\fedelemflowlist\FedElemFlowListMaster_v1.3.0_a79846d.parquet
# Summary:
#   total_flows: 17
#   input_flows: 10
#   output_flows: 7
#   reference_products: 1
#   unique_flow_types: 9
#   total_lca_amount: 26057242.590626873
#
# Flow Type Breakdown:
#   Chemicals: 6
#   Emissions to air: 4
#   Solid Input: 1
#   Solid Output: 1
#   Electricity: 1
#   Heat: 1
#   Solid Waste: 1
#   Wastewater: 1
#   Water: 1

# %% [markdown]
# ## <span style="color:black; font-weight:bold"> Step 6: Connect to openLCA </span>

# %% [markdown]
# #### <span style="color:black; font-weight:bold"> Notes on modeling this process using openLCA </span>

# %% [markdown]
# Before running the following code:
# - Open the software openLCA
# - Open an existing database or create a new one
# - Import libraries with existing processes
# - Use the IPC server from the Developer Tools
# - Run the server on port 8080

# %%
netl = NetlOlca()
netl.connect()
netl.read()
# Out:
# INFO Connected on http://localhost:8080
# INFO Read UUIDs from IPC connection.

# %% [markdown]
# #### <span style="color:black; font-weight:bold"> Define dataframe to be used </span>

# %% [markdown]
# <span style="color:black">
#
# The dataframe should have the following columns:
#
# | Flow_Name | LCA_Unit | LCA_Amount | Is_Input | Reference_Product | Flow_Type | Description |
#
# </span>

# %%
# Save the LCA data produced in previous steps in a dataframe called df
df = pd.read_csv('lca_df_finalized.csv')

# %% [markdown]
# #### <span style="color:black; font-weight:bold"> Enter Process Information </span>
#
# ##### <span style="color:black; font-weight:bold"> Unit Process Name </span>

# %%
process_name = "Test Process 1"  # Replace with the actual process name you want to use

# %% [markdown]
# ##### <span style="color:black; font-weight:bold"> Unit Process Description </span>

# %%
process_description = " Example Process Description"  # Replace with the actual process description you want to use

# %% [markdown]
# ##### <span style="color:black; font-weight:bold"> Create process with exchanges </span>

# %% [markdown]
# <span style="color:black">
#
# The functioning features include:
# * Create a new empty process
# * Create an exchange of the reference flow
#
# Intermediate functions/features that have been developed include:
# * Search for a flow by keyword
# * Search for processes that produce a given flow
#     * This feature is being optimized to minimize user waiting time
# * Create exchanges for elementary flows given their uuid, amount, and unit
#
# The features under development:
# * Create exchange for a given flow and process IDs
# * Develop an interactive user interface, allowing the user to create a new process in openLCA
# </span>

# %%
process = lca_prommis.create_lca.create_new_process(netl,df,process_name,process_description)
# TODO: give option for the user to enter another keyword when searching for a flow
# NOTE: For future discussion - is it better to select the flow then the provider (current status) or pick provider first then select relevant flows?
